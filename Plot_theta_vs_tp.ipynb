# %%
import numpy as np 
import scipy.special as sci
import math
#import matplotlib.pyplot as plt
import pylab as plt

t = linspace(0.2, 2, 400)
xthresh = 0.004
diff = a
below = diff < xthresh
above = diff >= xthresh
a = (sci.gammainc(3/2, t**-2))**4
b = (sci.gammainc(3/2,t**-2) )**6
c = (sci.gammainc(3/2, t**-2))**8
d = (sci.gammainc(3/2, t**-2))**9
e = (sci.gammainc(3/2, t**-2))**11
f = (sci.gammainc(3/2, t**-2))**26

plt.plot(t[above] , a[above], 'r',label='D=4') 
plt.plot(t[below] , a[below], 'r--') 
plt.plot(t, b, 'b',label='D=6') 
plt.plot(t, c, 'g',label='D=8') 
plt.plot(t, d, 'c',label='D=9') 
plt.plot(t, e, 'm',label='D=11') 
plt.plot(t, f, 'y',label='D=26') 

########################################



#########################################
plt.xlabel(r'$4\theta$')
plt.ylabel(r'$M^{D+1}_{proton}\,\tau_p$')
plt.title('Proton lifetime')
plt.grid(True)
plt.legend(loc='upper right')
#plt.ylim(-1.5, 2.0)
plt.show()
